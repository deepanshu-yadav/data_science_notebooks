# %%
# sudo -u postgres -i
# createdb movies_database
# psql  -d movies_database  -f MovieNow.sql

# %%
# %load_ext sql

# %%
# %sql postgresql://localhost/movies_database
# Out:
# (psycopg2.OperationalError) fe_sendauth: no password supplied
#
# (Background on this error at: http://sqlalche.me/e/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# # first install postgre on your system
# # sudo -U postgres
# # check psql is working
# # if not visit this https://stackoverflow.com/questions/42653690/psql-could-not-connect-to-server-no-such-file-or-directory-5432-error
#
# # Run ->  createdb movies_database
#
# # Then run this - >    psql -U postgres -d movies_database -a -f /home/deepanshu/Documents/repo/data_science_notebooks/dc/sql/main.sql
#
# # also can use sudo -u postgres psql -d movies_database -a -f /home/deepanshu/Documents/repo/data_science_notebooks/dc/sql/main.sql
#
#
# # Data Base will get created
#
#
# # For running a query use ->  psql -f  /home/deepanshu/Documents/repo/data_science_notebooks/dc/sql/query.sql  movies_database

# %%
# CREATE DATABASE yourdbname;
# CREATE USER youruser WITH ENCRYPTED PASSWORD 'yourpass';
# GRANT ALL PRIVILEGES ON DATABASE yourdbname TO youruser;
# ALTER USER user_name WITH PASSWORD 'new_password';

# %%
# Out:
# [sudo] password for deepanshu:

# %%
import psycopg2

# %%
# import getpass
# import os
# password = getpass.getpass()
# command = "sudo -i -u postgres" #can be any command but don't forget -S as it enables input from stdin
# os.system('echo %s | %s' % (password, command))
# os.system('psql')

#conn = psycopg2.connect("dbname=movies_database user=deepanshu password=deep123 ")

# %%
from configparser import ConfigParser
 
def config(filename='database.ini', section='postgresql'):
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)
 
    # get section, default to postgresql
    db = {}
    if parser.has_section(section):
        params = parser.items(section)
        for param in params:
            db[param[0]] = param[1]
    else:
        raise Exception('Section {0} not found in the {1} file'.format(section, filename))
 
    return db

# %%
#!/usr/bin/python
import psycopg2

 
def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config()
 
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)
      
        # create a cursor
        cur = conn.cursor()
        
   # execute a statement
        print('PostgreSQL database version:')
        cur.execute('SELECT version()')
 
        # display the PostgreSQL database server version
        db_version = cur.fetchone()
        print(db_version)
       
       # close the communication with the PostgreSQL
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            print('Database connection closed.')
 
 
if __name__ == '__main__':
    connect()
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 11.5 (Ubuntu 11.5-3.pgdg16.04+1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 5.4.0-6ubuntu1~16.04.11) 5.4.0 20160609, 64-bit',)
# Database connection closed.

# %%
def explore_renting():
    """ query data from the vendors table """
    conn = None
    try:
        params = config()
        conn = psycopg2.connect(**params)
        cur = conn.cursor()
        cur.execute("SELECT *   FROM renting ; ")
        print("The number of rented movies: ", cur.rowcount)
        row = cur.fetchone()
 
        while row is not None:
            print(row)
            row = cur.fetchone()
 
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
explore_renting()
# Out:
# The number of rented movies:  578
# (1, 41, 8, None, datetime.date(2018, 10, 9))
# (2, 10, 29, 10, datetime.date(2017, 3, 1))
# (3, 108, 45, 4, datetime.date(2018, 6, 8))
# (4, 39, 66, 8, datetime.date(2018, 10, 22))
# (5, 104, 15, 7, datetime.date(2019, 3, 18))
# (6, 50, 71, 7, datetime.date(2018, 10, 9))
# (7, 52, 21, None, datetime.date(2018, 11, 10))
# (8, 73, 65, 10, datetime.date(2018, 6, 5))
# (9, 78, 2, None, datetime.date(2017, 9, 3))
# (10, 121, 43, None, datetime.date(2017, 11, 8))
# (11, 61, 61, None, datetime.date(2017, 6, 4))
# (12, 52, 65, 10, datetime.date(2018, 6, 29))
# (13, 34, 58, 7, datetime.date(2017, 5, 14))
# (14, 8, 29, None, datetime.date(2018, 8, 3))
# (15, 13, 5, 10, datetime.date(2017, 11, 25))
# (16, 59, 59, None, datetime.date(2018, 8, 12))
# (17, 22, 46, 10, datetime.date(2019, 2, 16))
# (18, 36, 39, 10, datetime.date(2019, 3, 20))
# (19, 99, 12, None, datetime.date(2018, 9, 16))
# (20, 73, 32, None, datetime.date(2018, 9, 1))
# ...
